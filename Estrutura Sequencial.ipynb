# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print(" Alo mundo :) ")
# Out:
#  Alo mundo :)

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
Numero= int(input("Insira um numero" ))

print(Numero)
# Out:
# 800

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1= float(input("insira um numero"))
numero2= float(input("insira outro numero"))

resultado= numero1 + numero2

print(resultado )
# Out:
# 15.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1= float(input("Informe a primeira nota "))
nota2= float(input("informe a segunda nota "))
nota3= float(input("informe a terceira nota "))
nota4= float(input("informe a quarta nota "))

media= (nota1 + nota2 + nota3 + nota4) /4 

print(f"A media do aluno foi de {media}")
# Out:
# A media do aluno foi de 8.5

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metro = float(input("Informe a Metragem "))
conversao= metro * 100

resultado = conversao

print(f"{resultado} centimetros")
# Out:
# 3800.0 centimetros

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura= float(input("Informe a largura da sala " ))
cumprimento=float(input("informe o comprimento da sala "))
metro_qua= largura * cumprimento
print(f"A area da sala é de {metro_qua} m²")
# Out:
# A area da sala é de 375.0 m²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganho_hora= float(input("Valor do ganho por hora "))
horas_traba= float(input("Horas trabalhadas "))
salario= ganho_hora * horas_traba
print(f"O seu salário é de R${salario}")
# Out:
# O seu salário é de R$5400.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fahrenheit= float(input("Informe a temperatura em graus fahrenheit"))
graus= (fahrenheit - 32) * 5 / 9
print(f"{graus}°C convertido em Graus celcius")
# Out:
# 30.0°C convertido em Graus celcius

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
graus= float(input("Informe a temperatura em Graus Celcius ºC"))
fahrenheit= (graus * 9 / 5) + 32
print(f"{fahrenheit}°F convertido em Farenheit")
# Out:
# 77.0°F convertido em Farenheit

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura= float(input("informe a altura "))
peso= (72.7* altura) -58
print(f"Seu peso ideal é de: {peso:.2f} KG")
# Out:
# Seu peso ideal é de: 65.59 KG

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura=float(input("Informe sua altura "))
peso_hom= 72.7 * altura - 58
peso_mul= 62.1 * altura - 44.7

print(f"O Peso ideal com essa altura para homens {peso_hom:.2f} Kg")
print(f"O peso ideal com essa altura para mulheres {peso_mul:.2f} Kg")
# Out:
# O Peso ideal com essa altura para homens 65.59 Kg
# O peso ideal com essa altura para mulheres 60.87 Kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganho_hora= float(input("Informe quanto se ganha por hora "))
horas_traba= float(input("informe o numero de horas trabalhadas"))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario= ganho_hora * horas_traba
print(f"O salario bruto é de R$ {salario:.2f}")
# Out:
# O salario bruto é de R$ 4375.00

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desc_ir = salario * 0.11
print(f"Seu desconto de 11% IR é de {desc_ir:.2f} ")
# Out:
# Seu desconto de 11% IR é de 481.25

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desc_inss= salario * 0.08
print(f"Seu desconto de INSS é de {desc_inss:.2f}")
# Out:
# Seu desconto de INSS é de 350.00

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desc_sind= salario * 0.05
print(f"Seu desconto do sindicato foi de {desc_sind:.2f}")
# Out:
# Seu desconto do sindicato foi de 218.75

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liq= salario - desc_ir - desc_inss - desc_sind
print(f"Seu Salario liquido é de R${salario_liq:.2f}")
# Out:
# Seu Salario liquido é de R$3325.00

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
cumprimento= float(input("Informe o cumprimento do espaço "))
largura=float(input("informe a largura do espaço "))
area= cumprimento * largura 
print(f"O tamnaho da area é de {area}m²")

tinta= area /3 
print(f"Quantidade de tinta {tinta}L")

litros= tinta/ 18
print(f"quantidade de latas: {litros:.0f} Latas")
# Out:
# O tamnaho da area é de 600.0m²
# Quantidade de tinta 200.0L
# quantidade de latas 11 Latas

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho=float(input("Informe o tamanho do arquivo em MB "))
velocidade= float(input("Informe a velocidade da internet em Mbps "))

tamanho_megabit= tamanho * 8
tempo= tamanho_megabit / velocidade

tempo_minutos= tempo / 60
print(f"O tempo de download é de {tempo_minutos} minutos")
# Out:
# O tempo de download é de 13.333333333333334 minutos
